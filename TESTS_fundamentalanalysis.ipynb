# %%
import FundamentalAnalysis as fa
import pandas as pd
import numpy as np

# %%
api_key = "Here would go my personal API key"

# %%
ticker = "MSFT"   #Example for Microsoft (MSFT)

# %% [markdown]
# ### Show the available companies

# %%
companies = fa.available_companies(api_key)
companies
# Out:
#                                        name    price  \
# symbol
# SPY                  SPDR S&P 500 ETF Trust   372.70
# CMCSA                   Comcast Corporation    39.81
# KMI                     Kinder Morgan, Inc.    17.96
# INTC                      Intel Corporation    37.69
# MU                  Micron Technology, Inc.    58.31
# ...                                     ...      ...
# 5982.T                    Maruzen Co., Ltd.  1767.00
# 9845.T                   Parker Corporation   530.00
# 4685.T              Ryoyu Systems Co., Ltd.  1938.00
# NAAS                                            8.13
# CMRA    Comera Life Sciences Holdings, Inc.     3.05
#
#                             exchange exchangeShortName   type
# symbol
# SPY     New York Stock Exchange Arca              AMEX    etf
# CMCSA           NASDAQ Global Select            NASDAQ  stock
# KMI          New York Stock Exchange              NYSE  stock
# ...

# %% [markdown]
# ### Collect general company information

# %%
profile = fa.profile(ticker, api_key)
profile
# Out:
#                                                                    0
# symbol                                                          MSFT
# price                                                         243.62
# beta                                                        0.939201
# volAvg                                                      32234060
# mktCap                                                 1822041178112
# lastDiv                                                         2.42
# range                                                  241.52-349.67
# changes                                                     1.360001
# companyName                                    Microsoft Corporation
# currency                                                         USD
# cik                                                       0000789019
# isin                                                    US5949181045
# cusip                                                      594918104
# ...

# %% [markdown]
# ### Collect recent company quotes

# %%
quotes = fa.quote(ticker, api_key)
quotes
# Out:
#                                                  0
# symbol                                        MSFT
# name                         Microsoft Corporation
# price                                      243.525
# changesPercentage                         0.522166
# change                                    1.264999
# dayLow                                      241.52
# dayHigh                                     245.74
# yearHigh                                    349.67
# yearLow                                     241.52
# marketCap                          1821330636800.0
# priceAvg50                                275.3248
# priceAvg200                               301.5409
# volume                                    14190597
# avgVolume                                 32234060
# exchange                                    NASDAQ
# open                                        243.86
# previousClose                               242.26
# ...

# %% [markdown]
# ### Collect market cap and enterprise value

# %%
enterprise_value = fa.enterprise(ticker, api_key, period="annual") #period can be also "quarter" 
enterprise_value
# Out:
#                                              2021           2020  \
# symbol                                       MSFT           MSFT
# stockPrice                             284.910004     203.899994
# numberOfShares                         7547000000     7610000000
# marketCapitalization         2150215797923.900146  1551678953579
# minusCashAndCashEquivalents           11748000000    13576000000
# addTotalDebt                          67775000000    70998000000
# enterpriseValue              2206242797923.900391  1609100953579
#
#                                              2019          2018  \
# symbol                                       MSFT          MSFT
# stockPrice                             140.350006    105.370003
# numberOfShares                         7673000000    7700000000
# marketCapitalization         1076905596805.300049  811349020790
# minusCashAndCashEquivalents           11356000000   11946000000
# ...

# %% [markdown]
# ### Show recommendations of analysts

# %%
ratings = fa.rating(ticker, api_key)
ratings
# Out:
#            rating  ratingScore ratingRecommendation  ratingDetailsDCFScore  \
# date
# 2022-06-13     S-            5           Strong Buy                      5
# 2022-06-10     S-            5           Strong Buy                      5
# 2022-06-09     S-            5           Strong Buy                      5
# 2022-06-08     S-            5           Strong Buy                      5
# 2022-06-07     S-            5           Strong Buy                      5
# ...           ...          ...                  ...                    ...
# 2002-07-08      A            4                  Buy                      3
# 2002-07-05      A            4                  Buy                      3
# 2002-07-03      A            4                  Buy                      3
# 2002-07-02      A            4                  Buy                      3
# 2002-07-01      A            4                  Buy                      3
#
# ...

# %% [markdown]
# ### Obtain DCFs over time

# %%
dcf = fa.discounted_cash_flow(ticker, api_key, period="annual") #period can be also "quarter" 
dcf
# Out:
#                    2022        2021        2020        2019        2018  \
# date         2022-06-14  2021-06-30  2020-06-30  2019-06-30  2018-06-30
# Stock Price     245.595  284.910004  203.899994  140.350006  105.370003
# DCF          247.139164  286.466649  205.683962  141.830001  106.921432
#
#                    2017        2016        2015        2014        2013  ...  \
# date         2017-06-30  2016-06-30  2015-06-30  2014-06-30  2013-06-30  ...
# Stock Price   73.040001       56.68   46.880001   43.580002       31.85  ...
# DCF           74.029286   57.501451   47.564237   44.624586   32.304209  ...
#
#                    1995        1994        1993        1992        1991  \
# date         1995-06-30  1994-06-30  1993-06-30  1992-06-30  1991-06-30
# Stock Price    5.789063     3.21875      2.3125    2.285156    1.515625
# DCF            5.984637    3.370082    2.418796    2.373629    1.562899
#
#                    1990        1989        1988        1987        1986
# ...

# %% [markdown]
# ### Collect the Balance Sheet statements

# %%
balance_sheet = fa.balance_sheet_statement(ticker, api_key, period="annual") #period can be also "quarter" 
balance_sheet
# Out:
#                                                                                       2021  \
# reportedCurrency                                                                       USD
# cik                                                                             0000789019
# fillingDate                                                                     2021-07-29
# acceptedDate                                                           2021-07-29 16:21:55
# calendarYear                                                                          2021
# period                                                                                  FY
# cashAndCashEquivalents                                                         11748000000
# shortTermInvestments                                                          118586000000
# cashAndShortTermInvestments                                                   130334000000
# ...

# %% [markdown]
# ### Collect the Income Statements

# %%
income_statement = fa.income_statement(ticker, api_key, period="annual") #period can be also "quarter" 
income_statement
# Out:
#                                                                                       2021  \
# reportedCurrency                                                                       USD
# cik                                                                             0000789019
# fillingDate                                                                     2021-07-29
# acceptedDate                                                           2021-07-29 16:21:55
# calendarYear                                                                          2021
# period                                                                                  FY
# revenue                                                                       168088000000
# costOfRevenue                                                                  52232000000
# grossProfit                                                                   115856000000
# ...

# %% [markdown]
# ### Collect the Cash Flow Statements

# %%
cash_flow_statement = fa.cash_flow_statement(ticker, api_key, period="annual") #period can be also "quarter" 
cash_flow_statement
# Out:
#                                                                                        2021  \
# reportedCurrency                                                                        USD
# cik                                                                              0000789019
# fillingDate                                                                      2021-07-29
# acceptedDate                                                            2021-07-29 16:21:55
# calendarYear                                                                           2021
# period                                                                                   FY
# netIncome                                                                       61271000000
# depreciationAndAmortization                                                     11686000000
# deferredIncomeTax                                                                -150000000
# ...

# %% [markdown]
# ### Show Key Metrics

# %%
key_metrics= fa.key_metrics(ticker, api_key, period="annual") #period can be also "quarter"
key_metrics
# Out:
#                                                         2021           2020  \
# period                                                    FY             FY
# revenuePerShare                                    22.272161      18.793035
# netIncomePerShare                                    8.11859       5.818791
# operatingCashFlowPerShare                          10.168279       7.973062
# freeCashFlowPerShare                                7.435802       5.944021
# cashPerShare                                       17.269644      17.940473
# bookValuePerShare                                  18.813833      15.545861
# tangibleBookValuePerShare                          11.193454       8.924442
# shareholdersEquityPerShare                         18.813833      15.545861
# interestDebtPerShare                                9.291242       9.670039
# marketCap                               2150215797923.900146  1551678953579
# ...

# %% [markdown]
# ### Show a large set of in-depth ratios

# %%
financial_ratios = fa.financial_ratios(ticker, api_key, period="annual") #period can be also "quarter"
financial_ratios
# Out:
#                                           2021        2020        2019  \
# period                                      FY          FY          FY
# currentRatio                          2.079994    2.515765    2.528839
# quickRatio                            1.899196     2.33077    2.352967
# cashRatio                             0.132511    0.187747    0.163584
# daysOfSalesOutstanding               82.609675   81.697829   85.632574
# daysOfInventoryOutstanding           18.420509    15.01096   17.548241
# operatingCycle                      101.030183   96.708789  103.180814
# daysOfPayablesOutstanding           105.959852   99.254525   79.804941
# cashConversionCycle                  -4.929669   -2.545736   23.375874
# grossProfitMargin                     0.689258     0.67781     0.65902
# operatingProfitMargin                 0.415949    0.370304     0.34137
# pretaxProfitMargin                    0.423005    0.370842    0.347163
# ...

# %% [markdown]
# ### Show the growth of the company

# %%
growth = fa.financial_statement_growth(ticker, api_key, period="quarter") #period can be also "quarter"
growth
# Out:
#                                          2022-03   2021-12   2021-09  \
# period                                        Q3        Q2        Q1
# revenueGrowth                          -0.045778   0.14147 -0.018092
# grossProfitGrowth                      -0.029424  0.097787 -0.015236
# ebitgrowth                             -0.084641  0.099269  0.059859
# operatingIncomeGrowth                  -0.084641  0.099269  0.059859
# netIncomeGrowth                        -0.108553 -0.084857  0.245899
# epsgrowth                                 -0.108 -0.084249  0.246575
# epsdilutedGrowth                       -0.104839 -0.084871  0.248848
# weightedAverageSharesGrowth            -0.001599 -0.001065  -0.00186
# weightedAverageSharesDilutedGrowth      -0.00278 -0.001586 -0.001847
# dividendsperShareGrowth                 0.000094  0.107218 -0.000039
# operatingCashFlowGrowth                 0.753177 -0.409943  0.080581
# freeCashFlowGrowth                      1.326872 -0.540043  0.152048
# ...

# %% [markdown]
# ### General stock data

# %%
stock_data = fa.stock_data(ticker, period="ytd", interval="1d")
stock_data
# Out:
#                  close         low    volume        high        open  \
# 2022-01-03  334.750000  329.779999  28865100  338.000000  335.350006
# 2022-01-04  329.010010  326.119995  32674300  335.200012  334.829987
# 2022-01-05  316.380005  315.980011  40054300  326.070007  325.859985
# 2022-01-06  313.880005  311.489990  39646100  318.700012  313.149994
# 2022-01-07  314.040009  310.089996  32720000  316.500000  314.149994
# ...                ...         ...       ...         ...         ...
# 2022-06-08  270.410004  269.609985  17372300  273.000000  271.709991
# 2022-06-09  264.790009  264.630005  26439700  272.709991  267.779999
# 2022-06-10  252.990005  252.529999  31422800  260.579987  260.579987
# 2022-06-13  242.259995  241.529999  46103000  249.020004  245.110001
# 2022-06-14  243.549896  241.520004  14441475  245.740005  243.860001
#
#               adjclose
# 2022-01-03  333.282990
# 2022-01-04  327.568176
# 2022-01-05  314.993530
# 2022-01-06  312.504456
# ...

# %% [markdown]
# ### Detailed stock data

# %%
stock_data_detailed = fa.stock_data_detailed(ticker, api_key, begin="1985-01-01", end="2022-01-01")
stock_data_detailed
# Out:
#                   open        high         low       close    adjClose  \
# 2021-12-31   338.51001  339.359985  335.850006  336.320007   334.84613
# 2021-12-30  341.910004  343.130005  338.820007  339.320007  337.832977
# 2021-12-29  341.299988  344.299988  339.679993  341.950012  340.451477
# 2021-12-28  343.149994  343.809998  340.320007      341.25  339.754517
# 2021-12-27  335.459992  342.480011  335.429993  342.450012   340.94928
# ...                ...         ...         ...         ...         ...
# 1986-03-19    0.099826    0.100694    0.097222     0.09809    0.061655
# 1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062746
# 1986-03-17    0.100694    0.103299    0.100694    0.102431    0.064383
# 1986-03-14    0.097222    0.102431    0.097222    0.100694    0.063292
# 1986-03-13    0.088542    0.101563    0.088542    0.097222    0.061109
#
#                   volume unadjustedVolume   change changePercent       vwap  \
# ...

# %% [markdown]
# ### Download dividend history

# %%
dividends = fa.stock_dividend(ticker, api_key, begin="2000-01-01", end="2020-01-01")
dividends
# Out:
#                       label adjDividend dividend  recordDate paymentDate  \
# 2019-11-20  November 20, 19        0.51     0.51  2019-11-21  2019-12-12
# 2019-08-14    August 14, 19        0.46     0.46  2019-08-15  2019-09-12
# 2019-05-15       May 15, 19        0.46     0.46  2019-05-16  2019-06-13
# 2019-02-20  February 20, 19        0.46     0.46  2019-02-21  2019-03-14
# 2018-11-14  November 14, 18        0.46     0.46  2018-11-15  2018-12-13
# ...                     ...         ...      ...         ...         ...
# 2005-02-15  February 15, 05        0.08     0.08  2005-02-17  2005-03-10
# 2004-11-15  November 15, 04        3.08     3.08  2004-11-17  2004-12-02
# 2004-08-23    August 23, 04        0.08     0.08  2004-08-25  2004-09-14
# 2003-10-15   October 15, 03        0.16     0.16  2003-10-17  2003-11-07
# 2003-02-19  February 19, 03        0.08     0.08  2003-02-21  2003-03-07
#
#            declarationDate
# 2019-11-20      2019-09-18
# 2019-08-14      2019-06-12
# ...
